# %% [markdown]
# # Monte Carlo Option Pricing Engine
#
# Demo notebook. All pricing logic lives in the `monte_carlo_option_engine` package.

# %%
import numpy as np
import matplotlib.pyplot as plt

from monte_carlo_option_engine import (
    Market,
    Contract,
    ContractKind,
    black_scholes,
    market_from_yfinance,
    plot_paths,
    print_price,
    simulate_paths,
)

rng = np.random.default_rng(0)

# %% [markdown]
# ## Synthetic market
#
# Compare Monte Carlo to Black–Scholes for Europeans and a cash-or-nothing digital, then price an arithmetic Asian and a discrete up-and-out call.

# %%
mkt = Market(S=100, T=0.5, r=0.04, q=0.01, sigma=0.25)
K = 105

for kind in (ContractKind.euro_call, ContractKind.euro_put, ContractKind.digital_call):
    contract = Contract(K, kind)
    print_price(mkt, contract, trial_count=200_000, rng=rng)
    print(f"BS {kind}: {black_scholes(mkt, contract):.6f}\n")

print_price(mkt, Contract(K, ContractKind.asian_call), steps=200, trial_count=100_000, rng=rng)
print_price(
    mkt,
    Contract(K, ContractKind.up_and_out_call, B=130),
    steps=200,
    trial_count=100_000,
    rng=rng,
)

# %% [markdown]
# ## Path simulation
#
# `steps` and `n_paths` must be ints; `rng` must be a `numpy.random.Generator`.

# %%
paths = simulate_paths(mkt, steps=200, n_paths=10_000, rng=rng)

print(f"paths shape : {paths.shape}  # (steps + 1, n_paths)")
print(f"row 0 (=S0) : {paths[0, :3]}")
print(f"terminal S_T: {paths[-1, :3]}")
print(
    f"mean S_T    : {paths[-1].mean():.4f}  vs  "
    f"S0*exp((r-q)T) = {mkt.S * np.exp((mkt.r - mkt.q) * mkt.T):.4f}"
)

plot_paths(mkt, steps=200, n_paths=10, rng=rng)
plt.show()

# %% [markdown]
# ## Live snapshot (requires internet)
#
# `sigma` is 252-day historical volatility, not implied vol.

# %%
real_mkt = market_from_yfinance("AAPL", T=0.5, r=0.04)
strike = real_mkt.S * 1.05
call = Contract(strike, ContractKind.euro_call)
print_price(real_mkt, call, trial_count=100_000, rng=rng)
print(f"BS call: {black_scholes(real_mkt, call):.6f}")
